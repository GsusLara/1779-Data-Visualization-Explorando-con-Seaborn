# %% [markdown]
# <a href="https://colab.research.google.com/github/GsusLara/1779-Data-Visualization-Explorando-con-Seaborn/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv('credit_card.csv')

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# ###Traduciendo los titulos

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
cabecera = {
    'LIMIT_BAL' : 'Limite',
    'CHECKING_ACCOUNT':'cuenta_corriente',
    'EDUCATION':'escolaridad',
    'MARRIAGE':'estado_civil',
    'AGE':'edad',
    'BILL_AMT':'valor_de_factura',
    'PAY_AMT':'valor_de_pago',
    'DEFAULT':'moroso'
}

# %%
tarjetas = datos.rename(columns = cabecera)

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_de_factura  valor_de_pago  moroso
# 0          934.0122         0.0000       1
# 1          519.3975         0.0000       1
# 2         4223.5297       457.0698       0
# 3        14522.9563       602.2000       0
# 4       124060.1253     16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
nombreCc = {
    'Yes':'Si',
    'No':'No'
}

# %%
tarjetas.cuenta_corriente.map(nombreCc)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_de_factura  valor_de_pago  moroso
# 0          934.0122         0.0000       1
# 1          519.3975         0.0000       1
# 2         4223.5297       457.0698       0
# 3        14522.9563       602.2000       0
# 4       124060.1253     16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(nombreCc)

# %%
tarjetas
# Out:
#       Limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0       6022               Si       2.University      Married    24
# 1      36132               Si       2.University       Single    26
# 2      27099               Si       2.University       Single    34
# 3      15055               Si       2.University      Married    37
# 4     150550               No  3.Graduate School       Single    29
# ...      ...              ...                ...          ...   ...
# 1495   54198               Si  3.Graduate School       Single    27
# 1496   45165               No       2.University      Married    55
# 1497   78286               No  3.Graduate School       Single    34
# 1498    6022               No       2.University      Married    44
# 1499  183671               No  3.Graduate School       Single    31
#
#       valor_de_factura  valor_de_pago  moroso
# 0             934.0122         0.0000       1
# 1             519.3975         0.0000       1
# ...

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
nombresEscolaridad = {
    '2.University':'Universidad', '3.Graduate School': 'Escuela', '1.High School':'Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(nombresEscolaridad)

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
nombresEstadoC= {'Married': 'Casado', 'Single': 'Soltero' }

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(nombresEstadoC)

# %%
tarjetas
# Out:
#       Limite cuenta_corriente  escolaridad estado_civil  edad  \
# 0       6022               Si  Universidad       Casado    24
# 1      36132               Si  Universidad      Soltero    26
# 2      27099               Si  Universidad      Soltero    34
# 3      15055               Si  Universidad       Casado    37
# 4     150550               No      Escuela      Soltero    29
# ...      ...              ...          ...          ...   ...
# 1495   54198               Si      Escuela      Soltero    27
# 1496   45165               No  Universidad       Casado    55
# 1497   78286               No      Escuela      Soltero    34
# 1498    6022               No  Universidad       Casado    44
# 1499  183671               No      Escuela      Soltero    31
#
#       valor_de_factura  valor_de_pago  moroso
# 0             934.0122         0.0000       1
# 1             519.3975         0.0000       1
# 2            4223.5297       457.0698       0
# ...

# %% [markdown]
# #**Analisis de la informacion con seaborn**

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.2
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@gmail.com
# License: BSD (3-clause)
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by: missingno

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso
# 0         0.0000       1
# 1         0.0000       1
# 2       457.0698       0
# 3       602.2000       0
# 4     16560.5000       0

# %%
sns.distplot(tarjetas['Limite'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data= tarjetas, x = 'Limite', hue = 'escolaridad');

# %%
tarjetas['indice_de_uso'] = tarjetas['valor_de_factura'] / tarjetas['Limite']

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso  indice_de_uso
# 0         0.0000       1       0.155100
# 1         0.0000       1       0.014375
# 2       457.0698       0       0.155856
# 3       602.2000       0       0.964660
# 4     16560.5000       0       0.824046

# %%
sns.set_style('darkgrid')

# %%
sns.displot(data = tarjetas, x ='indice_de_uso',hue = 'escolaridad', palette = "inferno");

# %% [markdown]
# Hay un publico significativo que usa poco de su limite disponible

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso  indice_de_uso
# 0         0.0000       1       0.155100
# 1         0.0000       1       0.014375
# 2       457.0698       0       0.155856
# 3       602.2000       0       0.964660
# 4     16560.5000       0       0.824046

# %%
sns.countplot(data=tarjetas, x="cuenta_corriente", hue="moroso");

# %%
sns.catplot(data=tarjetas, x= "estado_civil", y = "Limite", hue= "moroso", dodge=True);

# %%
sns.swarmplot(data=tarjetas, x= "escolaridad", y = "indice_de_uso");
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 22.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 32.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data=tarjetas, x="escolaridad", y = "indice_de_uso", hue="moroso", palette="bone");

# %%
sns.violinplot(data=tarjetas, x="escolaridad", y = "indice_de_uso");

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso  indice_de_uso
# 0         0.0000       1       0.155100
# 1         0.0000       1       0.014375
# 2       457.0698       0       0.155856
# 3       602.2000       0       0.964660
# 4     16560.5000       0       0.824046

# %%
tarjetas.edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
grupos = [20,30,40,50,100]
rangos = ['entre 20 - 30', 'entre 30 - 40', 'entre 40 - 50', 'mayores a 50']
tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], grupos, labels=rangos)

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso  indice_de_uso     rango_edad
# 0         0.0000       1       0.155100  entre 20 - 30
# 1         0.0000       1       0.014375  entre 20 - 30
# 2       457.0698       0       0.155856  entre 30 - 40
# 3       602.2000       0       0.964660  entre 30 - 40
# 4     16560.5000       0       0.824046  entre 20 - 30

# %%
sns.boxplot(data=tarjetas, x="rango_edad", y="Limite");

# %%
tarjetas.head()
# Out:
#    Limite cuenta_corriente  escolaridad estado_civil  edad  valor_de_factura  \
# 0    6022               Si  Universidad       Casado    24          934.0122
# 1   36132               Si  Universidad      Soltero    26          519.3975
# 2   27099               Si  Universidad      Soltero    34         4223.5297
# 3   15055               Si  Universidad       Casado    37        14522.9563
# 4  150550               No      Escuela      Soltero    29       124060.1253
#
#    valor_de_pago  moroso  indice_de_uso     rango_edad
# 0         0.0000       1       0.155100  entre 20 - 30
# 1         0.0000       1       0.014375  entre 20 - 30
# 2       457.0698       0       0.155856  entre 30 - 40
# 3       602.2000       0       0.964660  entre 30 - 40
# 4     16560.5000       0       0.824046  entre 20 - 30

# %%
sns.displot(data=tarjetas, x='Limite', col='escolaridad', kind='kde', hue='rango_edad');

# %%
sns.scatterplot(data=tarjetas, x='indice_de_uso', y='valor_de_factura', hue= 'cuenta_corriente');

# %%
sns.lmplot(data=tarjetas, x='indice_de_uso', y='valor_de_factura', col='moroso');

# %%
sns.jointplot(data=tarjetas, x='edad', y = 'Limite', hue='moroso');

# %%
tarjetas.describe()
# Out:
#               Limite         edad  valor_de_factura  valor_de_pago  \
# count    1500.000000  1500.000000       1500.000000    1500.000000
# mean    51221.943333    35.212667      15459.869900    1984.869266
# std     39424.407462     9.274955      20722.582831    5296.771686
# min      3011.000000    21.000000         27.701200       0.000000
# 25%     18066.000000    28.000000       2035.586550     407.011925
# 50%     42154.000000    33.500000       7701.385250     759.374200
# 75%     72264.000000    41.000000      20671.568850    1705.279850
# max    210770.000000    75.000000     141792.506500   97022.850800
#
#             moroso  indice_de_uso
# count  1500.000000    1500.000000
# mean      0.078000       0.388237
# std       0.268261       0.341923
# min       0.000000       0.000188
# 25%       0.000000       0.049209
# 50%       0.000000       0.308976
# 75%       0.000000       0.704090
# max       1.000000       0.998010

# %%
sns.pairplot(data=tarjetas, hue='escolaridad', palette='cividis');
